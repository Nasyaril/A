# %% [markdown]
# <a href="https://colab.research.google.com/github/Nasyaril/A/blob/main/soal2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# membaca gambar berwarna
img = cv2.imread('/content/suisei.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# ukuran sampling
sizes = [512, 256, 128, 64]

plt.figure(figsize=(10,8))

for i, size in enumerate(sizes):

    resized = cv2.resize(img, (size, size))

    plt.subplot(2,2,i+1)
    plt.imshow(resized)
    plt.title(f'{size} x {size}')
    plt.axis('off')

plt.show()
